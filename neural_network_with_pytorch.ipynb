# %% [markdown]
# <a href="https://colab.research.google.com/github/codingjobrice/AI/blob/main/neural_network_with_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

device = torch.device('cpu')

N, Din, Dout = 64,4,2

x=torch.randn(N,Din,device = device)
y=torch.randn(N,Dout,device = device)
w=torch.randn(Din,Dout,device = device)

lr=1e-6
loss_arr = []
for t in range(5000):
  y_pred = x.mm(w)

  loss = 0.5*(y_pred-y).pow(2).sum()
  loss_arr.append(loss)

  grad_y_pred=(y_pred-y)
  grad_w = x.t().mm(grad_y_pred)

  w -= lr* grad_w

import matplotlib.pyplot as plt

plt.plot(loss_arr)
